# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Following is the list of locations that we stored in text file in the previous program. I could have continued the program from there as well but for the sake of simplicity and easy understanding I'll write a new block for this. (We can also take these values from the file as well)

# %%
locations = ['India', 'Mumbai, India', 'India', 'India', '', 'India', 'Bharat Mata', 'Indore, India', 'Ahmedabad', 'kerala kozhikode kattilapeedik', 'Celestial Bodies', 'Mumbai, India', 'Mussorie, India', '', '221C Boogie street എൽപൽഘട്ടിനോ', 'Bangalore', 'India', 'TRIVANDRUM', 'Cochin, India', 'India', '', 'Kozhikode, India', '', 'noren nation', 'Hyderabad, India', 'Kolkata, West Bengal', 'Tamil Nadu, India', 'Around you.', 'Abu Dhabi, UAE', 'Kerala, India', 'India', 'India', 'South Africa', 'Kolkata', 'Mumbai', 'Bailey she/they (fan acc)', "Yoongi's heart", 'Pune, India', 'India', '', '3 E 64 St NY, New York USA', 'New Delhi, India', '', 'Dehradun, India', 'Always on Twitter', 'Kerala, India  \n🇮🇳', 'Jawaharlal Nehru University', 'Pine Ridge', 'Princeton, NJ', 'Mumbai, India', 'Bengaluru South, India', 'Hyderabad', 'Germany', '', 'Mumbai, India', ' 🇮🇳', 'India', 'ÜT: 18.986431,72.823769', 'Ponnani, India', '', 'New Delhi', 'Gurgaon, India', 'India', 'Kochi, India', 'Kerala, India', 'Mother Earth', 'Qatar', 'New Delhi, India', 'Hyderabad, India', "between Jungkook's thighs", 'Chengannur, India', 'Chennai, India', 'Bengaluru, India', 'kalamassry', 'Bengaluru || Kannur, Kerala', 'Bengaluru, India', 'Mumbai', 'THRISSUR', 'kolkata, india', 'Trivandrum, India', 'Mumbai, India', '', "We're listening, let's talk.", '', 'United Kingdom', '', 'Ambalavayal, Wayanad, Kerala', 'New Delhi, India', 'India', 'Tamil Nadu, India', '', 'Abu Dhabi', '', '', 'Thiruvananthapuram, New Delhi', 'Kerala, India', 'Kolkata, India', '', '', 'India', 'singap', '', 'Surat, India', 'Kolkata', 'God’s Own Country', 'Abu Dhabi', 'India', '', 'Bhagyanagar (Hyderabad)', 'chennai India', 'CHENNAI', 'New Delhi', 'Stockholm, Sweden', 'ടൈംലൈൻ', '', 'New Delhi', 'India', 'Manchester, England', 'Cochin, India', '', '', 'Planet Earth', 'Nowhere', 'Hyderabad, India', 'Dubai, United Arab Emirates', '', 'Malappuram City', '', 'Bengaluru', 'Tamil Nadu, India', '', 'Hyderabad, Telangana State', 'Mumbai, India', 'New Delhi, India', 'Kollam, India', 'India', 'Bengaluru, Karnataka', 'Chennai, India', '', 'Hyderabad, India', 'Kannur', 'kerala india', 'Mulund, Mumbai', 'Trivandrum', 'Kerala, India', '', 'Mumbai', '', '', '', 'Trivandrum, Kerala', 'Mumbai', 'Chennai, India', '', 'West Bengal, India', 'India', '', 'Mumbai', 'Gurgaon, India', 'hyderabad', 'Chennai', '', 'New Delhi', '', 'Kerala, India', 'United States', '', 'India', '', 'Kanyakumari', 'Kerala, India', '', 'Versmold, Deutschland', 'Abu Dhabi', 'Saket, New Delhi', 'Born in Kerala; Now in Delhi', 'Dubai', 'Bangalore, Delhi, Mumbai, Chennai, Hyderabad', 'Abu Dhabi', 'Hyderabad, India', 'Ontario, Canada', '', 'Mumbai, India', 'ғʀᴏᴍ ᴇᴀʀᴛʜ 22,88', 'India', 'Chennai, India', 'Hyderabad', 'Ghaziabad, India', 'kariamkod Nileshwar', 'New Delhi, India', '', 'NewDelhi-India', 'Bangtan Universe \n✨\n/  \n🇮🇳', '', 'India', 'United Arab Emirates', 'Delhi, India', 'New Delhi, India', 'India', 'Earth', 'India', 'New Delhi, Bharat', '', 'Kerala കേരളം', '', '', 'United Kingdom', 'India', 'Bengaluru, India', 'Kerala, India', 'Kannur', '', 'Pulamanthole', 'Kerala, India', 'New Delhi, India', 'On the Road!', '', 'india', 'Bengaluru, India', 'India', 'Gurgaon, India', 'RomanEmpire', 'Chandigarh, India', '', 'Kerala, India', '', 'India', '', 'Faridabad, India', 'Hyderabad, India', '', 'New Delhi, India', 'Loving 방탄소년단', 'Chennai, India', 'Kottayam, India', 'Chandigarh, India', '', 'Mumbai', 'India', 'Kerala, India', 'Singapore', 'Kerala, India', 'London - Hyderabad -Karimnagar', 'BANGTANLAND  \n🇮🇳\n 💜\n ❣️\n 🍃', 'FB.com/BreakMovies', 'Coimbatore, India', 'United Kingdom', 'Land of the gods - Bharatha', 'India, NL', 'Delhi, India, Bharat', 'Chennai, India', 'Kerala, India', 'New Delhi', 'Chhattisgarh, India', 'Italy', 'Pondicherry, India', 'Kerala, India', '','Bangalore, India', '?????? \n??\n????????????', '', '', 'New Delhi, India', 'Kannur, Kerala', 'New Delhi, India', 'Mumbai, India', 'California, USA', 'Roma', 'Assam, India', 'India', '', '', 'Anand, Gujarat', 'Chennai, India', 'New Delhi', 'Navyarkapura', 'God’s Own Country', 'Kochi', 'Pisa, Tuscany', 'India', 'Antarctica', 'India', 'India', 'India', 'Stockholm, Sweden', 'Fingal, Ireland', 'Springfield', '', 'Kolkata, India', '', 'Surrey, UK', 'India', 'India', '', 'Chennai', 'India', 'Daman, union territory of Daman and Diu, India', '', 'Mumbai, India', 'New Delhi', 'Bhubaneswar, Odisha', '', '', 'Tamil Nadu, India', 'Hoshiarpur ~ Punjab ~ India', 'United Arab Emirates', '', 'Worldwide \n??', 'bengladesh', 'Ernakulam', 'bharat', 'New Delhi', 'Chennai, India', 'Mumbai, India', 'Kerala, India', 'India', 'Noida, India', 'New Delhi, India', 'Kolkata, West Bengal', '', 'Kerala, India', 'New York I Texas I Punjab', 'Istanbul, Turkey', '', 'Israel  \n????', 'India', '½ way btwn d gutter & d stars', 'New Delhi, Bharat', 'Mantralaya, Mumbai', 'Kerala, India', 'Ahmedabad', 'New Delhi, India', 'India', 'Bhubaneswar...Odisha', 'Nagpur, India', '', 'unofficial account', 'London, England', 'New Delhi, India', 'New Delhi/Calcutta/Chennai', 'New Delhi, India', 'New Delhi-110029', 'Hyderabad, India', 'Hyderabad, India', '', 'Trivandrum, India', 'India', 'Malappuram City', 'Varanasi, New Delhi', 'New Delhi, India', 'Jodhpur, Rajasthan(India)', 'Jammu and Kashmir', 'India', 'DG CRPF, NewDelhi, India', 'Bahadurgarh, India', 'New Delhi, India', 'India','India', 'Cochin Bharat', 'Kerala, India', '', 'India', 'Dubai, United Arab Emirates', 'United Arab Emirates', '', 'Lucknow, India', 'Jhajjar, India', 'New Delhi, India', 'Mumbai', '', 'The Universe  \n??', 'New Delhi, India', 'Mumbai, India', 'Delhi/Manipur', 'India', 'West Bengal, India', 'India', '?????????', 'Pale blue dot', 'Hyderabad, India', 'Kerala, India', '', 'Chennai, India', 'Ghazipur , Kanpur, (UP) India', 'Thiruvananthapuram', 'Kerala, India', 'Vellore', 'West Block A | Sree Kanteerava Stadium', 'India', 'Hyderabad, India', 'Chennai, India', 'Mumbai, India', 'Trivandrum, India', 'Mumbai, India', 'Hyderabad, India', 'A-009, SEC-68 , NOIDA', 'Planet Earth', '', 'home', 'Mumbai - Singapore', 'India', '', 'India', 'BRD medical college ,Gorakhpur', 'Cochin, India', '', '', 'New Delhi', 'Chicago, IL', 'India', 'India', '', 'New Delhi, India', 'India', 'Thiruvananthapuram / Mumbai', '', 'Beypore,calicut,kerala,India', 'ÜT: 18.986431,72.823769', 'New Delhi, India', 'London/Delhi', '', 'Kochi', 'Noida, India', 'India', 'New Delhi, India', 'Chennai', 'Indore, India', 'Leicester, England', '', '', 'Chennai, India', 'Trivandrum City, Trivandrum', 'Trivandrum, India', 'United Kingdom', 'New Delhi, India', 'India', 'Here and there', 'Bangalore', 'India', 'India', 'New Delhi, India', 'Delhi', 'Pala', "Land's End", 'Chennai, India', 'Itanagar, India', '', '', 'New Delhi, India', 'New Delhi, India', 'Kottayam, India', 'Alcatraz', "Where I'M meant to be ..", 'Hyderabad, India', 'Jammu, Jammu And Kashmir', 'Jirapur, Bhopal, Mumbai', '', '', 'Gurgaon, India', 'My House,My State, My Country', 'Kerala, India', 'Chennai, India', 'New Delhi, India', 'India', 'Kannur, ????, India', 'Mannat - WhatsApp: 9941893723', 'New Delhi, India', 'Chennai - India', 'Bombay', '', 'Mumbai, India', 'the universe is my oyster', 'Bengaluru, India', 'Chennai, India', '','Bengaluru', 'Kerala', 'Kolkata', 'Cochin, India', 'New Delhi', 'Kolkata', 'FB.com/BreakMovies', 'Patna, India', 'Delhi, London, San Francisco', 'Chennai, India', 'India', 'Jaipur', 'Sangrur(Punjab)', 'New Delhi, India', 'Chennai, India', '', 'Bombay', 'Utopia', 'Bengaluru, India', 'Mumbai, India.', 'Gandhinagar, India', 'Bengaluru, India', '', 'India', 'India', 'Chennai, India', 'Chennai, India', '', 'Bhubaneshwar, India', 'Thiruvananthapuram, India', 'Bengaluru', 'BTS', 'Washington, DC', 'India', 'Mumbai.India', '', 'Bengaluru, India', 'Dubai, United Arab Emirates', 'Delhi', 'New Delhi', 'India', 'Mumbai', 'India', 'New Delhi, India', 'New Delhi,India', 'New Delhi, India', 'Bharat', 'United States of America', 'Bangalore', 'Punjab, India', '', 'Mumbai', 'India', 'Mumbai, India', 'Chennai, India', '', 'Kochi', 'Chennai, India', 'Hyderabad', 'Cochin', 'Tamil Nadu, India', 'Bangalore, India', 'Shimla HP', 'Kanhangad', 'CHENNAI', '', 'India', 'India', '', 'Bangalore', 'New Delhi, India', 'India', '', 'Rajasthan, India', 'Bharata', 'kasaragod', 'India', 'United States,India', '', 'Bengaluru, India', 'Bharat', 'New Delhi', 'South Africa', 'Thyagaraya Nagar, Chennai', 'Genius Lab / OT7 club', 'Gods own country', 'Cochin, India', 'New Delhi, India', 'Hyderabad, India', 'Alappuzha, Kerala, India', 'Nadakkavu, Kozhikode', 'Noida, India', 'Chennai, India', 'New Delhi, India','Disabled ( Cleanest city )', 'Tamil Nadu, India', 'New Delhi, India', 'New Delhi', 'Bengaluru, India', '', '', 'India', '', 'Chandigarh, India', 'Lucknow, India', 'Kerala, India', 'Pune', 'cochin mera jaan', 'New Delhi', 'India', '', 'Delhi, India', 'Born in Kerala; Now in Delhi', 'Northern Ireland', 'Chennai', 'Vermont', 'Delhi, India', '', 'India', 'India/Singapore', 'Kolkata, India', 'Ambala, India', '12, Tughlak Lane, New Delhi', '', 'Yamuna Nagar,Haryana,India', 'Between Venus and Mars', 'Bengaluru, India', 'Bockenheim', 'India', '', 'Chennai, India', 'Goa | Delhi', 'New Delhi, India', ' ??\nBhilwara', 'India', 'Mohenjodaro', 'Bangalore', 'New Delhi, India', 'Chennai, India', 'India', 'Chennai', 'DGP HQs LUCKNOW', 'Kerala, India', 'New Delhi', 'Pathanamthitta, India', 'Hyderabad, India', 'Puducherry', 'Delhi, India', '', 'Hyderabad, India', '', '', 'New Delhi, India', 'Srinivas Puri, New Delhi', 'Chennai, India', 'Pakistan', '??????', 'india', '?? ?s?? ???? ??a?? \n??', 'Bangalore', 'Mumbai, India', 'India', '', '', 'Kerala, India', 'Mumbai', 'Akhand Bharat', 'Hyderabad, India', 'Madras', 'Cochin, India', 'Mylapore, India', 'Hyderabad | Chennai | Mumbai', "God's Own Country", 'Cochin, India', 'Telangana State, India', 'Delhi/Hyderabad...INDIA', 'Riyadh, Kingdom of Saudi Arabia', 'Kilmacolm, Scotland', 'Mumbai', '', 'Chennai, India', 'India', 'Hyderabad, India', 'Kerala, India', '', 'India', '', '', 'Pinarayi, Kannur, Kerala', 'Bengaluru, India', 'New Delhi, India', 'Chennai', 'Delhi/Noida', 'London, UK', '', 'Bengaluru / Bangalore , India', 'Hyderabad, India', '', 'Bharat', 'kochi, India', 'Mumbai, India', '', '', 'Mumbai', 'Mumbai', 'Bengaluru, India', '', 'India', 'India', 'India', '?????', 'Gurgaon', 'Chennai,India', 'Chennai','Aukaat', 'New Delhi', 'Noida', 'New Delhi , India.', 'Kerala, India', 'Princeton, NJ', 'India', 'Kolkata, India', 'India', 'New Delhi', 'Kerala, India', 'Chennai, India', '', 'Cochin , Kerala, India', 'Mumbai, India', 'New Delhi, India', '???? ???? ?? ??', 'Bengaluru', 'Mumbai', 'Maharashtra, India', 'Fatehpur, Uttar Pradesh', '', 'India', 'Worldwide', 'New Delhi', 'Kolkata', 'India', '', 'Mumbai, India', 'Panaji, India', 'Namapally, Hyderabad', 'Vadodra, Gujarat, India', 'Mumbai', 'Kullu', 'New Delhi', 'Medanta the Medicity gurugram', 'Mumbai', 'New Delhi', 'Karnataka', 'DGP HQS Lucknow, UP', 'Chennai, India', 'Palakkad', 'Bengaluru, Karnataka', 'Chennai', 'New Delhi, India  \n????', 'India', 'India', 'Mumbai', 'United States', 'Global Citizen', '', 'N 161,Flat No 101,Thapar House', '', 'Arizona, USA', 'Mumbai, India', 'kanyakumari,Tamil Nadu,India', 'Delhi', '', 'Pune, India', 'New Delhi', 'India','Chennai, India', 'Maharashtra, India', 'Canada', 'Mumbai, India', 'India', 'New Delhi', 'Mumbai', 'Mumbai', 'Living out of a suitcase', 'Kuala Lumpur, Malaysia', 'Delhi, India', 'KERALA , INDIA', 'Bahrain', 'Chennai, India', '', '', 'Kochi, Kerala', 'Kerala, India', 'Hyderabad, India', 'New Delhi | Mumbai', 'Hyderabad, India', 'Hanoi, Vietnam', 'India', 'Kochi, India', 'Bangalore', 'Johannesburg, South Africa', 'Bangalore Ke Traffic me.', '', 'Chennai, India', 'India', 'India', 'Bengaluru, India', 'Cuttack, Odisha,India', 'Kerala, India', 'New Delhi, Bharat', '', 'New Delhi', 'Bhagyanagar (Hyderabad)', 'New Delhi', 'Vijay Fans Heart  \n??', 'Bombay', 'New Delhi, India', '', 'Guwahati', 'Mumbai, Maharashtra', 'New Delhi, India', 'Towards Jannah Insha Allah!', '', '', 'Bhopal', 'Oxford, England', 'Chennai, India', 'Pune - Ranebennur', 'Gurgaon, India', 'New Delhi', 'Delhi, India', '','Kochi,kerala,india', 'India', 'Pakistan', 'Washington, DC', 'Coimbatore, India', 'Ahmadi 61001, Kuwait', 'Mysore, Karnataka, India', 'Birmingham, England', 'CONGRESS WORKER INC', 'Coimbatore, India', 'Chennai', 'India', 'Bombay, MH, India, Earth', 'Chennai', 'india', 'On the Road!', 'Chennai', 'new delhi', 'India', 'Kerala, India', '', 'Chennai, India', 'Nomads Land','India', 'New Delhi, India', 'Bhubaneswar, Odisha', '', 'India', 'India , Kolkata', 'Land of the gods - Bharatha', 'New Delhi, India', 'Bangalore', 'Mechanicsburg, PA', '', 'Pune, India', '', '', 'Jammu, Srinagar', '????????, ????', 'Bangalore', '', 'India', '3rd Planet from the SUN', 'Trivandrum, India', 'ÜT: 18.986431,72.823769', 'New Delhi, India', 'Nepal','bengaluru, india', 'India', 'Guwahati, India', 'Canada', 'chennai', 'Mysore, New Delhi', 'Kerala, India', 'Delhi, India', 'India', 'India', 'Bengaluru, India', 'Delhi', 'Delhi', 'Macondo', 'Silchar, Assam', '', 'Hyderabad, India', 'South Asia', 'New Delhi', 'Kerala, India', 'Patiala', 'India', 'England', 'Hyderabad', '', '', 'Chennai, India', 'Chepauk, Chennai', '#Gujarat to #Bangalore', 'Hyderabad', 'Mumbai', 'Trivandrum, India', 'India', 'Bengaluru, India', 'Cochin, India', 'Secretariat | Chennai | TN', 'Kerala, India', 'Hyderabad, India', 'New Delhi-Lucknow', 'Mumbai, India', 'Bengaluru, India', 'Bhubaneswar, Orissa', 'Cochin India', 'India', 'Thiruvananthapuram, Kerala, In', '', 'Kolkata, India', '???????, ????', '', 'Amphoe Phra Nakhon Si Ayutthay', 'Noida', 'Akhand Bharath', '', 'India', 'New Delhi, India', 'Chennai, India', 'Jangpura, New Delhi', "Bharat- 'Vishwa Guru'", 'India', 'Bangalore', 'Kozhikode, India', 'Mumbai', 'Noida, India', '', 'Kerala, India', 'Faridabad, India', 'India', '','', 'Sultanpur, India', 'Cochin, India', 'kerala,India', 'Chennai, India.', 'Tamil Nadu, India', 'Kottayam, India', 'Kerala', 'Like us On FB -', '??????????, ????', '??? Jeddah', 'eomuk', 'Chennai, India', 'KL, Malaysia', 'Mumbai', 'Kundapura (in Udupi)', 'Travel Across India & Report', 'Kerala', 'India', 'I N D I A', 'India  \n????', 'India', 'Bangalore', 'MUMBAI', 'Chennai, India', 'India', 'National Capital Region', 'India','India', '', 'Bengaluru,India', 'India', '', 'Christchurch City, New Zealand', 'Feminist AF', '', 'India', 'India', 'Kottayam, India', 'Mumbai, India', 'New Delhi, India', '', 'Calicut | Kozhikode', 'India', 'Chennai, India', 'Global', 'India', 'Bengaluru, India', 'Andhra Pradesh, India', 'Jaipur', '', 'India', 'India', '', 'India', 'India','India', '', 'New Delhi, India', 'New Delhi/Kanniyakumari', '', 'Cochin, India', 'Uppsala, Sweden', 'Chandigarh, New Delhi', '', 'India', 'India', 'Around you.', 'Galaxy far far away', 'Ahmedabad, Gujarat', 'Jawaharlal Nehru University', 'New Delhi, India', '', 'Chennai', '??????', 'Bombay', '', 'New Delhi, India', 'Salem', 'New Delhi, India', 'Chennai , India', 'new delhi', 'Mumbai, India', 'India', 'Mumbai', 'India', 'Cochin, India', 'Chikkamagaluru, India', 'Gorre lokam', 'Kolkata, India', '', 'inspiredindianfoundation.org', 'Salerno, Campania', 'India', '', 'India', 'Bangalore India', 'Patna', 'Siddipet Hyderabad', '', '', '', '', 'Malabar, Kerala', 'India', 'Mumbai, India', 'india', 'Mumbai, India', 'Bengaluru, India', 'Rajasthan, India', '', 'Mumbai', '', 'Pune, India', 'India', 'India', 'India', '', 'New Delhi, India', 'Perumbavoor, Ernakulam, Kerala', 'India', 'India','India', 'India', 'Trivandrum, India', 'Venice, CA', '', 'Thiruvananthapuram', 'Chennai, India', '', 'India', 'New Delhi & Thiruvananthapuram', 'India', 'Bollywood', 'Mumbai, India', ' ????', 'India', '', 'Hyderabad, India', 'Bangalore', 'India', 'República da Índia', 'Bangalore', '', 'Cherthala, India', '', '????', '', 'JNU', 'Gokarna,Karnataka,India', 'India', 'Mumbai', 'Singapore', 'Waterloo, Ontario', 'Mumbai, India', 'Hyderabad, India', 'Bengaluru, India', 'Global Girl', 'Mumbai, India', 'Trivandrum', 'Bangalore', 'india', 'Bangalore', 'Chennai, India', 'India', 'India', 'Kochi', 'Bhopal, India', '????? ?????', 'Patna, India', 'Srinagar J&K', 'India', '', 'United Kingdom', 'Derby', 'Bangalore, Delhi, Mumbai, Chennai, Hyderabad', 'Mumbai', 'Bengaluru, India | New York', 'Wirral/Wherever The Ball Rolls', 'Hyderabad', 'Thiruvananthapuram', '', '??????', 'Hyderabad', 'New Delhi', '', 'Official','Liberty High', 'Seven Hills', 'Delhi, India, Bharat', 'Tamil Nadu, India', 'India', 'Chennai, India', '', 'Kerala, India', 'Mumbai, India', '12, Tughlak Lane, New Delhi', 'Chennai, India', '', 'India', 'Chennai, India', '????', '', 'Kerala/New Delhi', '', 'Maharashtra, India', 'Catalonia', 'India & UAE', 'London England', 'India', 'India', 'Ludhiana, India', 'Mumbai, India', 'Hither Thither', '', '', 'Chennai, India', 'Banglore', 'Madurai / DC', 'Chennai, India', '', 'Fort Tondiarpet, India', 'Madras !!!', 'India', 'Anthiyur, India', "?? ????rh?rs'? \n??", 'New Delhi, India', '', 'Noida, India', '', 'Gujarat, India', '', 'India', 'Bengaluru, India', 'Thiruvananthapuram, Keralam', 'India', 'Roorkee, New Delhi India', 'New Delhi, India', 'India', 'Province of Leningrad, Russia', 'Kollywood', 'Kollywood Film Industry', '', '', 'India', 'Somalia', '', 'Bharath', 'In your Heart', 'Mumbai, India', '', 'India', 'Dark side of the moon', 'Hyderabad, Telangana', '', 'India', 'Kerala, India', 'India', 'Ramanathapuram', 'Delhi', 'OT7', 'Maharashtra, India', 'Chennai, India', 'India', 'Kerala,  \n????', 'Mumbai, Maharashtra', 'New Delhi, India', '', 'Mumbai', 'New Delhi', 'India', 'Shimoga, India', 'Chennai, India','Chennai, India', 'Pune, Maharashtra', '', 'New Delhi, India', 'On stage!', 'Bangalore, Karnataka', 'New Delhi, India', 'Chennai, India', 'Maharashtra State,India', 'Hindusthan', 'India', 'Pune, Maharashtra, INDIA', '', 'India', 'mostly on the road', 'Trivandrum, India','Trivandrum, India', 'National Capital Region, India', '', '', 'Dallas, TX', 'Cochin, India', 'Hyderabad, India', 'Kerala, India', 'Ernakulam, Kerala', 'Chennai, India', 'New Delhi', 'Bengaluru, India', 'Pakistan, Turkey, South Africa', 'Hyderabad, India', 'Mumbai','India', 'India', 'India', 'New Delhi, India', 'Anjar India', 'Mumbai, India', 'Kochi', 'Canada', 'Hyderabad', 'Chennai', 'New Delhi', '', 'Bengaluru, India', 'India', 'facebook.com/SRKUniverse','Thiruvananthapuram', '', 'mumbai', 'Between a cage and a flight', 'Mumbai, India', 'India- Sullia,Bengaluru,Delhi', 'US, India, RSA', 'Chennai, India', 'Chennai, India', '', 'Kerala, India', '', 'Hyderabad', 'India', 'Tamil Nadu, India', '', 'India', 'Kolkata, India', 'India', 'Delhi', 'Jerusalem', 'Chennai, India', 'India', 'RM 2  \n🎵', 'Kerala', 'New Delhi, India', 'India', 'New Delhi, India', 'Mumbai', 'India', 'New Delhi', 'Cochin, India', 'New Delhi, India', '', 'India', '', 'India/Canada', 'Chennai, India', 'Kerala, India','ÜT: 12.975347,77.607725', 'Mumbai, India', 'New Delhi, India', 'Chennai', 'Mumbai, India', 'Trivandrum, Kerala, India', '', 'Dubai | Kerala', 'New Delhi, India', 'Chennai, India', 'India', 'Planet Earth', 'Chennai, India', 'India', 'India', 'Kolkata - Dhaka - Cambridge', '', 'Andimukk', 'Bangtan Universe \n✨\n/  \n🇮🇳', 'INDIA', '', 'भारत - India', 'New Delhi, India', 'Tiruvalla', 'Dehradun, India', 'Chennai', 'Atlanta, GA', '', 'worldwide', '', 'Everywhere!!!', 'India', '', 'Kochi , India', 'New Delhi, India', 'Cochin, India', 'Gujarat', 'London, England', 'New Delhi | Hometown - Kanpur', 'Kerala/ Bengaluru/ Chennai', '', 'India, Hyderabad', 'Rawalpindi, Pakistan', ' ❤️', 'Bengaluru, India', '', "SRK's Country", 'Chennai, India', '', 'New Delhi', 'Kerala', 'Kochi', 'Chennai, India', '', 'City Football Academy Melb', 'New Delhi', 'Kashmir', 'India', 'Trivandrum,India', '', 'Vatican City', 'Pondicherry, India', '', 'Bengaluru, India', 'Kerala, India', 'Bhubaneswar', 'Garhshankar, India', 'Chennai, India', 'chennai,Tamilnadu', 'Los Angeles, CA', 'New Delhi, India', '', 'India', 'kottayam, kerala - India', 'India', 'Worldwide', 'Bengaluru, India', 'New Delhi', 'Trivandrum, India', 'Kozhikode, India', 'India', 'New Delhi', 'Slough, South East', '', 'New Delhi, Kolkata, Ballia', 'India', 'Bengaluru, Karnataka', "Find me in SRK's arms", 'Sydney, AUSTRALIA', 'Karnataka, India', 'India', '', '', 'Global Citizen', 'Mumbai', 'Hindustan', 'Chennai', 'India', 'Tripunithura,Ernakulam,Kerala', 'India', '', 'Maharashtra, India', 'Chennai, India', '', 'Kerala, India', 'Chennai, India', '', 'Qatar','India', 'Lucknow, India', 'Chennai, India', 'Mumbai', 'Udaipur, India', 'India', 'Chennai, India', 'Tamil Nadu, India', 'New Delhi, India', 'महाराष्ट्र, भारत', '', 'Bangalore', 'kerala, India', 'New Delhi, India', 'Thiruvallavazhu,Keralam', 'Ahmedabad', 'Delhi/NCR, Gorakhpur', 'Thalassery, India', 'Kerala, India', 'Pune/Mumbai', '', 'Mumbai', 'Chandigarh, India', 'Bengaluru, India', 'Cochin, India', 'Chennai', '', 'India', 'New Delhi', 'Kolkata', '9729506771', 'India', 'New York, USA', 'World of Qubec', '', 'New Delhi', 'Chennai, India', 'Nellai', '', '@greenpeace @amnesty @LeagueACS #KeepTheBan #EndBSL #OpCircus #OpZoo', ' 📰\nSince February 01, 2018', '', 'Worldwide', 'Kerala, India', 'Kerala, India', 'Karachi/Dubai','Mumbai, India', 'Kerala, India', '', 'Bengaluru, India', 'Cochin, India', 'Tamil Nadu, India', 'Pakistan', 'India', 'India', 'New Delhi', 'Bengaluru, India', 'Heaven/Hell', 'Delhi via Lucknow & Kozhikode', 'Bad Place', 'Mumbai', '', 'India', 'Karnataka, India', 'Bengaluru, India', 'India', 'Hyderabad, India', 'palakkad,kerala', 'Tenebrocity', '', 'Mumbai, India', 'Chennai', 'India', 'Ayodhya, India', 'New Delhi, India', 'noida', 'Lahore, Pakistan', 'India', 'Trivandrum, State of Kerala, India', 'Mumbai and where my mobile is', 'India', '', 'Coimbatore', 'Mumbai, India', 'Follow my page on facebook @RaghubarDas', 'Dalhousie, himachal Pradesh,IN', 'Bengaluru, India', 'Hyderabad, India', '', '', 'India', 'Mumbai', 'New Delhi, India', '']

# %% [markdown]
# #### Following Code:
#
# 1. Cleans locations based on what I observed (eg. '&' could be used as a separation indicator so as '/')
#
# 2. Drops the location 'India' as we need to classify users based on states and cities in India thus the word 'India' doesn't help us achieve our goal
#
# 3. Remove left space and right space (if any for any words eg. 'Pune, Maharashtra')

# %%
s = ','
s = s.join(locations)

print(s)

s1 = s.replace('&',',').replace('/',',').replace('India','')
print()
print(s1)

separated_locations = s1.split(',')
print()
print(separated_locations)

separated_locs = []
for w in separated_locations:
    w1 = w.lstrip()
    w2 = w1.rstrip()
    separated_locs.append(w2)
print()
print(separated_locs)
# Out:
# India,Mumbai, India,India,India,,India,Bharat Mata,Indore, India,Ahmedabad,kerala kozhikode kattilapeedik,Celestial Bodies,Mumbai, India,Mussorie, India,,221C Boogie street എൽപൽഘട്ടിനോ,Bangalore,India,TRIVANDRUM,Cochin, India,India,,Kozhikode, India,,noren nation,Hyderabad, India,Kolkata, West Bengal,Tamil Nadu, India,Around you.,Abu Dhabi, UAE,Kerala, India,India,India,South Africa,Kolkata,Mumbai,Bailey she/they (fan acc),Yoongi's heart,Pune, India,India,,3 E 64 St NY, New York USA,New Delhi, India,,Dehradun, India,Always on Twitter,Kerala, India
# ...

# %% [markdown]
# Following is the path where I've stored the files of cities which are statewise classified. This will be our reference data

# %%
cd E:/Projects/Kerala Floods/Files
# Out:
# E:\Projects\Kerala Floods\Files

# %%
files = ['Andhra Pradesh.xlsx','Arunachal Pradesh.xlsx','Assam.xlsx','Bihar.xlsx','Chhattisgarh.xlsx',
         'DN.xlsx','Diu.xlsx','Delhi.xlsx','Goa.xlsx','Gujrat.xlsx','Haryana.xlsx','HP.xlsx','JK.xlsx',
         'Jharkhand.xlsx','Karnataka.xlsx','Kerala.xlsx','MP.xlsx','MH.xlsx','Manipur.xlsx','Meghalaya.xlsx',
         'Mizoram.xlsx','Nagaland.xlsx','Orissa.xlsx','Pondicherry.xlsx','Punjab.xlsx','RJ.xlsx','Sikkim.xlsx',
         'TN.xlsx','Tripura.xlsx','UP.xlsx','UT.xlsx','WB.xlsx']

states =  ['Andhra Pradesh','Arunachal Pradesh','Assam','Bihar','Chhattisgarh',
         'Dadra-Nagar Haveli','Diu','Delhi','Goa','Gujrat','Haryana','Himachal Pradesh','Jammu & Kashmir',
         'Jharkhand','Karnataka','Kerala','MP','Maharashtra','Manipur','Meghalaya',
         'Mizoram','Nagaland','Orissa','Pondicherry','Punjab','Rajasthan','Sikkim',
         'Tamil Nadu','Tripura','UP','Uttarakhand','West Bengal']

places = []

for i in range(len(files)):
    file = pd.read_excel(files[i])

    new = []
    for city in file['Cities'] :
        new.append(city)

    s = '.'
    s = s.join(new)
    m = s.split('.')

    state = []
    for w in m:
        w1 = w.lstrip()
        w2 = w1.rstrip()
        state.append(w2)
    places.append(state)

# %%
count_states = np.zeros(len(places))
for city in separated_locs:
    for i in range(len(places)):
        if city in places[i]:
            count_states[i] += 1
        
for i in range(len(places)):
    print(states[i] + ':', count_states[i])
# Out:
# Andhra Pradesh: 47.0
# Arunachal Pradesh: 3.0
# Assam: 7.0
# Bihar: 6.0
# Chhattisgarh: 5.0
# Dadra-Nagar Haveli: 2.0
# Diu: 1.0
# Delhi: 153.0
# Goa: 2.0
# Gujrat: 10.0
# Haryana: 14.0
# Himachal Pradesh: 5.0
# Jammu & Kashmir: 7.0
# Jharkhand: 2.0
# Karnataka: 82.0
# Kerala: 133.0
# MP: 8.0
# Maharashtra: 105.0
# Manipur: 3.0
# Meghalaya: 2.0
# Mizoram: 0.0
# Nagaland: 0.0
# Orissa: 9.0
# Pondicherry: 2.0
# Punjab: 10.0
# Rajasthan: 10.0
# Sikkim: 2.0
# Tamil Nadu: 116.0
# Tripura: 2.0
# UP: 25.0
# Uttarakhand: 5.0
# West Bengal: 24.0

# %%
cities = ['Mumbai','New Delhi', 'Kolkata','Bengaluru','Chennai','Thiruvananthapuram','Hyderabad','Trivandrum']

count_cities = np.zeros(len(cities))

for city in separated_locs:
    for i in range(len(cities)):
        if city == cities[i]:
            count_cities[i] += 1
for i in range(len(cities)):        
    print(cities[i] + ':', str(count_cities[i]))

f = plt.figure()
plt.axes(ylim = (0,150))
plt.bar(cities,count_cities,color = 'r')
plt.title('POPULAR CITIES')
plt.xticks(rotation='vertical')
#f.savefig("Popular_Cities.pdf", bbox_inches='tight')
# Out:
# Mumbai: 83.0
# New Delhi: 128.0
# Kolkata: 17.0
# Bengaluru: 43.0
# Chennai: 90.0
# Thiruvananthapuram: 10.0
# Hyderabad: 43.0
# Trivandrum: 17.0
# ([0, 1, 2, 3, 4, 5, 6, 7], <a list of 8 Text xticklabel objects>)

# %%
x = ['Delhi','Tamil Nadu','Maharashtra','Kerala','Karnataka','Andhra Pradesh']
y = []
for i in range(len(x)):
    y.append(count_states[states.index(x[i])])

f = plt.figure()

plt.axes(ylim = (0,200))
plt.bar(x,y,color = 'b')
plt.title('POPULAR STATES')

#f.savefig("stand_with_kerala_plot1.pdf", bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'POPULAR STATES')
